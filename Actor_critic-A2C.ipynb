# %% [markdown]
# https://github.com/rlcode/reinforcement-learning

# %%
import sys
import gym
import pylab
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
EPISODES = 1000


# A2C(Advantage Actor-Critic) agent for the Cartpole
class A2CAgent:
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size
        self.value_size = 1

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.99
        self.actor_lr = 0.001
        self.critic_lr = 0.005

        # create model for policy network
        self.actor = self.build_actor()
        self.critic = self.build_critic()

        if self.load_model:
            self.actor.load_weights("./save_model/cartpole_actor.h5")
            self.critic.load_weights("./save_model/cartpole_critic.h5")

    # approximate policy and value using Neural Network
    # actor: state is input and probability of each action is output of model
    def build_actor(self):
        actor = Sequential()
        actor.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        actor.add(Dense(self.action_size, activation='softmax',
                        kernel_initializer='he_uniform'))
        actor.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actor.compile(loss='categorical_crossentropy',
                      optimizer=Adam(lr=self.actor_lr))
        return actor

    # critic: state is input and value of state is output of model
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(24, input_dim=self.state_size, activation='relu',
                         kernel_initializer='he_uniform'))
        critic.add(Dense(self.value_size, activation='linear',
                         kernel_initializer='he_uniform'))
        critic.summary()
        critic.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return critic

    # using the output of policy network, pick action stochastically
    def get_action(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
        return np.random.choice(self.action_size, 1, p=policy)[0]

    # update policy network every episode
    def train_model(self, state, action, reward, next_state, done):
        target = np.zeros((1, self.value_size))
        advantages = np.zeros((1, self.action_size))

        value = self.critic.predict(state)[0]
        next_value = self.critic.predict(next_state)[0]

        if done:
            advantages[0][action] = reward - value
            target[0][0] = reward
        else:
            advantages[0][action] = reward + self.discount_factor * (next_value) - value
            target[0][0] = reward + self.discount_factor * next_value

        self.actor.fit(state, advantages, epochs=1, verbose=0)
        self.critic.fit(state, target, epochs=1, verbose=0)

# %%
# In case of CartPole-v1, maximum length of episode is 500
env = gym.make('CartPole-v1')
# get size of state and action from environment
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# make A2C agent
agent = A2CAgent(state_size, action_size)

scores, episodes = [], []

for e in range(EPISODES):
    done = False
    score = 0
    state = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        if agent.render:
            env.render()

        action = agent.get_action(state)
        next_state, reward, done, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        # if an action make the episode end, then gives penalty of -100
        reward = reward if not done or score == 499 else -100

        agent.train_model(state, action, reward, next_state, done)

        score += reward
        state = next_state

        if done:
            # every episode, plot the play time
            score = score if score == 500.0 else score + 100
            scores.append(score)
            episodes.append(e)
            pylab.plot(episodes, scores, 'b')
            pylab.savefig("./save_graph/cartpole_a2c.png")
            print("episode:", e, "  score:", score)

            # if the mean of scores of last 10 episode is bigger than 490
            # stop training
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                break
                # sys.exit()

    # save the model
#     if e % 50 == 0:
#         agent.actor.save_weights("./save_model/cartpole_actor.h5")
#         agent.critic.save_weights("./save_model/cartpole_critic.h5")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 170
# Trainable params: 170
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 16.0
# episode: 1   score: 23.0
# episode: 2   score: 37.0
# episode: 3   score: 24.0
# episode: 4   score: 21.0
# episode: 5   score: 25.0
# episode: 6   score: 51.0
# episode: 7   score: 46.0
# episode: 8   score: 27.0
# episode: 9   score: 14.0
# episode: 10   score: 32.0
# episode: 11   score: 9.0
# episode: 12   score: 17.0
# episode: 13   score: 15.0
# episode: 14   score: 8.0
# episode: 15   score: 15.0
# episode: 16   score: 17.0
# episode: 17   score: 18.0
# episode: 18   score: 39.0
# episode: 19   score: 18.0
# episode: 20   score: 31.0
# episode: 21   score: 27.0
# episode: 22   score: 31.0
# episode: 23   score: 13.0
# episode: 24   score: 36.0
# episode: 25   score: 37.0
# episode: 26   score: 13.0
# episode: 27   score: 12.0
# episode: 28   score: 35.0
# episode: 29   score: 89.0
# episode: 30   score: 17.0
# episode: 31   score: 15.0
# episode: 32   score: 18.0
# episode: 33   score: 27.0
# episode: 34   score: 26.0
# episode: 35   score: 75.0
# episode: 36   score: 37.0
# episode: 37   score: 22.0
# episode: 38   score: 23.0
# episode: 39   score: 23.0
# episode: 40   score: 23.0
# episode: 41   score: 39.0
# episode: 42   score: 14.0
# episode: 43   score: 40.0
# episode: 44   score: 15.0
# episode: 45   score: 20.0
# episode: 46   score: 54.0
# episode: 47   score: 16.0
# episode: 48   score: 29.0
# episode: 49   score: 30.0
# episode: 50   score: 13.0
# episode: 51   score: 33.0
# episode: 52   score: 23.0
# episode: 53   score: 17.0
# episode: 54   score: 11.0
# episode: 55   score: 11.0
# episode: 56   score: 30.0
# episode: 57   score: 66.0
# episode: 58   score: 29.0
# episode: 59   score: 27.0
# episode: 60   score: 14.0
# episode: 61   score: 47.0
# episode: 62   score: 54.0
# episode: 63   score: 26.0
# episode: 64   score: 16.0
# episode: 65   score: 15.0
# episode: 66   score: 12.0
# episode: 67   score: 15.0
# episode: 68   score: 18.0
# episode: 69   score: 44.0
# episode: 70   score: 21.0
# episode: 71   score: 48.0
# episode: 72   score: 39.0
# episode: 73   score: 18.0
# episode: 74   score: 15.0
# episode: 75   score: 35.0
# episode: 76   score: 23.0
# episode: 77   score: 95.0
# episode: 78   score: 10.0
# episode: 79   score: 15.0
# episode: 80   score: 32.0
# episode: 81   score: 32.0
# episode: 82   score: 37.0
# episode: 83   score: 14.0
# episode: 84   score: 41.0
# episode: 85   score: 17.0
# episode: 86   score: 12.0
# episode: 87   score: 9.0
# episode: 88   score: 52.0
# episode: 89   score: 72.0
# episode: 90   score: 37.0
# episode: 91   score: 60.0
# episode: 92   score: 22.0
# episode: 93   score: 46.0
# episode: 94   score: 37.0
# episode: 95   score: 31.0
# episode: 96   score: 34.0
# episode: 97   score: 50.0
# episode: 98   score: 31.0
# episode: 99   score: 48.0
# episode: 100   score: 55.0
# episode: 101   score: 44.0
# episode: 102   score: 37.0
# episode: 103   score: 33.0
# episode: 104   score: 75.0
# episode: 105   score: 88.0
# episode: 106   score: 17.0
# episode: 107   score: 55.0
# episode: 108   score: 27.0
# episode: 109   score: 105.0
# episode: 110   score: 69.0
# episode: 111   score: 26.0
# episode: 112   score: 56.0
# episode: 113   score: 42.0
# episode: 114   score: 58.0
# episode: 115   score: 46.0
# episode: 116   score: 46.0
# episode: 117   score: 91.0
# episode: 118   score: 88.0
# episode: 119   score: 43.0
# episode: 120   score: 76.0
# episode: 121   score: 29.0
# episode: 122   score: 49.0
# episode: 123   score: 88.0
# episode: 124   score: 40.0
# episode: 125   score: 48.0
# episode: 126   score: 27.0
# episode: 127   score: 27.0
# episode: 128   score: 39.0
# episode: 129   score: 61.0
# episode: 130   score: 58.0
# episode: 131   score: 48.0
# episode: 132   score: 56.0
# episode: 133   score: 50.0
# episode: 134   score: 56.0
# episode: 135   score: 66.0
# episode: 136   score: 25.0
# episode: 137   score: 29.0
# episode: 138   score: 150.0
# episode: 139   score: 30.0
# episode: 140   score: 45.0
# episode: 141   score: 54.0
# episode: 142   score: 59.0
# episode: 143   score: 90.0
# episode: 144   score: 44.0
# episode: 145   score: 48.0
# episode: 146   score: 215.0
# episode: 147   score: 31.0
# episode: 148   score: 66.0
# episode: 149   score: 127.0
# episode: 150   score: 66.0
# episode: 151   score: 51.0
# episode: 152   score: 82.0
# episode: 153   score: 52.0
# episode: 154   score: 84.0
# episode: 155   score: 92.0
# episode: 156   score: 146.0
# episode: 157   score: 68.0
# episode: 158   score: 98.0
# episode: 159   score: 64.0
# episode: 160   score: 126.0
# episode: 161   score: 52.0
# episode: 162   score: 52.0
# episode: 163   score: 129.0
# episode: 164   score: 156.0
# episode: 165   score: 72.0
# episode: 166   score: 176.0
# episode: 167   score: 162.0
# episode: 168   score: 247.0
# episode: 169   score: 139.0
# episode: 170   score: 73.0
# episode: 171   score: 90.0
# episode: 172   score: 245.0
# episode: 173   score: 98.0
# episode: 174   score: 124.0
# episode: 175   score: 257.0
# episode: 176   score: 297.0
# episode: 177   score: 271.0
# episode: 178   score: 105.0
# episode: 179   score: 65.0
# episode: 180   score: 225.0
# episode: 181   score: 136.0
# episode: 182   score: 123.0
# episode: 183   score: 383.0
# episode: 184   score: 196.0
# episode: 185   score: 230.0
# episode: 186   score: 120.0
# episode: 187   score: 109.0
# episode: 188   score: 92.0
# episode: 189   score: 123.0
# episode: 190   score: 181.0
# episode: 191   score: 156.0
# episode: 192   score: 157.0
# episode: 193   score: 137.0
# episode: 194   score: 91.0
# episode: 195   score: 126.0
# episode: 196   score: 122.0
# episode: 197   score: 208.0
# episode: 198   score: 222.0
# episode: 199   score: 159.0
# episode: 200   score: 144.0
# episode: 201   score: 125.0
# episode: 202   score: 226.0
# episode: 203   score: 126.0
# episode: 204   score: 186.0
# episode: 205   score: 209.0
# episode: 206   score: 291.0
# episode: 207   score: 151.0
# episode: 208   score: 115.0
# episode: 209   score: 69.0
# episode: 210   score: 112.0
# episode: 211   score: 127.0
# episode: 212   score: 151.0
# episode: 213   score: 186.0
# episode: 214   score: 122.0
# episode: 215   score: 206.0
# episode: 216   score: 246.0
# episode: 217   score: 281.0
# episode: 218   score: 235.0
# episode: 219   score: 144.0
# episode: 220   score: 200.0
# episode: 221   score: 103.0
# episode: 222   score: 498.0
# episode: 223   score: 398.0
# episode: 224   score: 153.0
# episode: 225   score: 269.0
# episode: 226   score: 123.0
# episode: 227   score: 211.0
# episode: 228   score: 274.0
# episode: 229   score: 500.0
# episode: 230   score: 200.0
# episode: 231   score: 125.0
# episode: 232   score: 229.0
# episode: 233   score: 500.0
# episode: 234   score: 500.0
# episode: 235   score: 389.0
# episode: 236   score: 473.0
# episode: 237   score: 156.0
# episode: 238   score: 145.0
# episode: 239   score: 122.0
# episode: 240   score: 148.0
# episode: 241   score: 145.0
# episode: 242   score: 155.0
# episode: 243   score: 207.0
# episode: 244   score: 170.0
# episode: 245   score: 251.0
# episode: 246   score: 172.0
# episode: 247   score: 154.0
# episode: 248   score: 103.0
# episode: 249   score: 110.0
# episode: 250   score: 131.0
# episode: 251   score: 117.0
# episode: 252   score: 107.0
# episode: 253   score: 41.0
# episode: 254   score: 49.0
# episode: 255   score: 55.0
# episode: 256   score: 58.0
# episode: 257   score: 115.0
# episode: 258   score: 119.0
# episode: 259   score: 148.0
# episode: 260   score: 156.0
# episode: 261   score: 212.0
# episode: 262   score: 221.0
# episode: 263   score: 324.0
# episode: 264   score: 312.0
# episode: 265   score: 327.0
# episode: 266   score: 120.0
# episode: 267   score: 500.0
# episode: 268   score: 464.0
# episode: 269   score: 307.0
# episode: 270   score: 437.0
# episode: 271   score: 356.0
# episode: 272   score: 268.0
# episode: 273   score: 324.0
# episode: 274   score: 303.0
# episode: 275   score: 234.0
# episode: 276   score: 226.0
# episode: 277   score: 200.0
# episode: 278   score: 13.0
# episode: 279   score: 14.0
# episode: 280   score: 15.0
# episode: 281   score: 7.0
# episode: 282   score: 9.0
# episode: 283   score: 9.0
# episode: 284   score: 9.0
# episode: 285   score: 7.0
# episode: 286   score: 9.0
# episode: 287   score: 8.0
# episode: 288   score: 8.0
# episode: 289   score: 9.0
# episode: 290   score: 8.0
# episode: 291   score: 9.0
# episode: 292   score: 9.0
# episode: 293   score: 9.0
# episode: 294   score: 8.0
# episode: 295   score: 8.0
# episode: 296   score: 11.0
# episode: 297   score: 10.0
# episode: 298   score: 11.0
# episode: 299   score: 9.0
# episode: 300   score: 10.0
# episode: 301   score: 9.0
# episode: 302   score: 10.0
# episode: 303   score: 69.0
# episode: 304   score: 223.0
# episode: 305   score: 13.0
# episode: 306   score: 129.0
# episode: 307   score: 110.0
# episode: 308   score: 142.0
# episode: 309   score: 141.0
# episode: 310   score: 129.0
# episode: 311   score: 140.0
# episode: 312   score: 147.0
# episode: 313   score: 159.0
# episode: 314   score: 142.0
# episode: 315   score: 184.0
# episode: 316   score: 164.0
# episode: 317   score: 181.0
# episode: 318   score: 189.0
# episode: 319   score: 193.0
# episode: 320   score: 192.0
# episode: 321   score: 189.0
# episode: 322   score: 275.0
# episode: 323   score: 198.0
# episode: 324   score: 183.0
# episode: 325   score: 274.0
# episode: 326   score: 89.0
# episode: 327   score: 290.0
# episode: 328   score: 350.0
# episode: 329   score: 444.0
# episode: 330   score: 153.0
# episode: 331   score: 500.0
# episode: 332   score: 500.0
# episode: 333   score: 500.0
# episode: 334   score: 500.0
# episode: 335   score: 500.0
# episode: 336   score: 500.0
# episode: 337   score: 500.0
# episode: 338   score: 500.0
# episode: 339   score: 500.0
# episode: 340   score: 500.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/usuario/anaconda3/envs/GPUV2/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
agent.actor.save_weights("./save_model/cartpole_actor.h5")
agent.critic.save_weights("./save_model/cartpole_critic.h5")
