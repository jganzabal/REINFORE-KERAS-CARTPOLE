# %%
import threading
import numpy as np
import tensorflow as tf
import pylab
import time
import gym
from keras.layers import Dense, Input
from keras.models import Model
from keras.optimizers import Adam
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# global variables for threading
episode = 0
scores = []

EPISODES = 2000

# This is A3C(Asynchronous Advantage Actor Critic) agent(global) for the Cartpole
# In this example, we use A3C algorithm
class A3CAgent:
    def __init__(self, state_size, action_size, env_name):
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # get gym environment name
        self.env_name = env_name

        # these are hyper parameters for the A3C
        self.actor_lr = 0.001
        self.critic_lr = 0.001
        self.discount_factor = .99
        self.hidden1, self.hidden2 = 24, 24
        self.threads = 8

        # create model for actor and critic network
        self.actor, self.critic = self.build_model()

        # method for training actor and critic network
        self.optimizer = [self.actor_optimizer(), self.critic_optimizer()]

        self.sess = tf.InteractiveSession()
        K.set_session(self.sess)
        self.sess.run(tf.global_variables_initializer())

    # approximate policy and value using Neural Network
    # actor -> state is input and probability of each action is output of network
    # critic -> state is input and value of state is output of network
    # actor and critic network share first hidden layer
    def build_model(self):
        state = Input(batch_shape=(None,  self.state_size))
        shared = Dense(self.hidden1, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_uniform')(state)

        actor_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='glorot_uniform')(shared)
        action_prob = Dense(self.action_size, activation='softmax', kernel_initializer='glorot_uniform')(actor_hidden)

        value_hidden = Dense(self.hidden2, activation='relu', kernel_initializer='he_uniform')(shared)
        state_value = Dense(1, activation='linear', kernel_initializer='he_uniform')(value_hidden)

        actor = Model(inputs=state, outputs=action_prob)
        critic = Model(inputs=state, outputs=state_value)

        actor._make_predict_function()
        critic._make_predict_function()

        actor.summary()
        critic.summary()

        return actor, critic

    # make loss function for Policy Gradient
    # [log(action probability) * advantages] will be input for the back prop
    # we add entropy of action probability to loss
    def actor_optimizer(self):
        action = K.placeholder(shape=(None, self.action_size))
        advantages = K.placeholder(shape=(None, ))

        policy = self.actor.output

        good_prob = K.sum(action * policy, axis=1)
        eligibility = K.log(good_prob + 1e-10) * K.stop_gradient(advantages)
        loss = -K.sum(eligibility)

        entropy = K.sum(policy * K.log(policy + 1e-10), axis=1)

        actor_loss = loss + 0.01*entropy

        optimizer = Adam(lr=self.actor_lr)
        updates = optimizer.get_updates(self.actor.trainable_weights, [], actor_loss)
        train = K.function([self.actor.input, action, advantages], [], updates=updates)
        return train

    # make loss function for Value approximation
    def critic_optimizer(self):
        discounted_reward = K.placeholder(shape=(None, ))

        value = self.critic.output

        loss = K.mean(K.square(discounted_reward - value))

        optimizer = Adam(lr=self.critic_lr)
        updates = optimizer.get_updates(self.critic.trainable_weights, [], loss)
        train = K.function([self.critic.input, discounted_reward], [], updates=updates)
        return train

    # make agents(local) and start training
    def train(self):
        # self.load_model('./save_model/cartpole_a3c.h5')
        agents = [Agent(i, self.actor, self.critic, self.optimizer, self.env_name, self.discount_factor,
                        self.action_size, self.state_size) for i in range(self.threads)]

        for agent in agents:
            agent.start()

        while True:
            time.sleep(20)

            plot = scores[:]
            pylab.plot(range(len(plot)), plot, 'b')
            pylab.savefig("./save_graph/cartpole_a3c.png")

            self.save_model('./save_model/cartpole_a3c.h5')

    def save_model(self, name):
        self.actor.save_weights(name + "_actor.h5")
        self.critic.save_weights(name + "_critic.h5")

    def load_model(self, name):
        self.actor.load_weights(name + "_actor.h5")
        self.critic.load_weights(name + "_critic.h5")

# This is Agent(local) class for threading
class Agent(threading.Thread):
    def __init__(self, index, actor, critic, optimizer, env_name, discount_factor, action_size, state_size):
        threading.Thread.__init__(self)

        self.states = []
        self.rewards = []
        self.actions = []

        self.index = index
        self.actor = actor
        self.critic = critic
        self.optimizer = optimizer
        self.env_name = env_name
        self.discount_factor = discount_factor
        self.action_size = action_size
        self.state_size = state_size

    # Thread interactive with environment
    def run(self):
        global episode
        env = gym.make(self.env_name)
        while episode < EPISODES:
            state = env.reset()
            score = 0
            while True:
                action = self.get_action(state)
                next_state, reward, done, _ = env.step(action)
                score += reward

                self.memory(state, action, reward)

                state = next_state

                if done:
                    episode += 1
                    print("episode: ", episode, "/ score : ", score)
                    scores.append(score)
                    self.train_episode(score != 500)
                    break

    # In Policy Gradient, Q function is not available.
    # Instead agent uses sample returns for evaluating policy
    def discount_rewards(self, rewards, done=True):
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        if not done:
            running_add = self.critic.predict(np.reshape(self.states[-1], (1, self.state_size)))[0]
        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_rewards[t] = running_add
        return discounted_rewards

    # save <s, a ,r> of each step
    # this is used for calculating discounted rewards
    def memory(self, state, action, reward):
        self.states.append(state)
        act = np.zeros(self.action_size)
        act[action] = 1
        self.actions.append(act)
        self.rewards.append(reward)

    # update policy network and value network every episode
    def train_episode(self, done):
        discounted_rewards = self.discount_rewards(self.rewards, done)

        values = self.critic.predict(np.array(self.states))
        values = np.reshape(values, len(values))

        advantages = discounted_rewards - values

        self.optimizer[0]([self.states, self.actions, advantages])
        self.optimizer[1]([self.states, discounted_rewards])
        self.states, self.actions, self.rewards = [], [], []

    def get_action(self, state):
        policy = self.actor.predict(np.reshape(state, [1, self.state_size]))[0]
        return np.random.choice(self.action_size, 1, p=policy)[0]

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

env.close()

global_agent = A3CAgent(state_size, action_size, env_name)
global_agent.train()
# Out:
# WARNING:tensorflow:From /home/usuario/anaconda3/envs/GPUV2/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 745
# Trainable params: 745
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/usuario/anaconda3/envs/GPUV2/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode:  1 / score :  14.0
# episode:  2 / score :  16.0
# episode:  3 / score :  13.0
# episode:  4 / score :  16.0
# episode:  5 / score :  17.0
# episode:  6 / score :  25.0
# episode:  7 / score :  20.0
# episode:  8 / score :  11.0
# episode:  9 / score :  65.0
# episode:  10 / score :  13.0
# episode:  11 / score :  episode: episode: 14.0 12 / score :  16.0
# episode:  13 / score :  17.0
#
#  14 / score :  12.0
# episode:  15 / score :  32.0
# episode:  16 / score :  27.0
# episode:  17 / score :  19.0
# episode:  18 / score :  20.0
# episode:  19 / score :  15.0
# episode:  20 / score :  19.0
# episode:  21 / score :  15.0
# episode:  22 / score :  35.0
# episode:  23 / score :  11.0
# episode:  24 / score :  18.0
# episode:  25 / score :  15.0
# episode:  26episode:  / score :  19.0
#  27 / score :  23.0
# episode:  episode: 28 / score :  32.0
#  29 / score :  38.0
# episode:  30 / score :  20.0
# episode:  31 / score :  19.0
# episode:  32 / score :  21.0
# episode:  33 / score :  10.0
# episode:  34 / score :  25.0
# episode:  35 / score : episode:   3628.0
# / score :  16.0
# episode: episode:  38 / score :  16.0
#  37 / score :  20.0
# episode:  39 / score :  22.0
# episode:  40 / score :  15.0
# episode:  41 / score :  33.0
# episode:  42 / score :  38.0
# episode: episode:  44 / score :  10.0
#  43episode:  / score :  16.0
#  45 / score :  14.0
# episode:  46 / score : episode:  19.0
#  47 / score :  26.0
# episode:  48 / score :  24.0
# episode:  49 / score :  29.0
# episode:  50 / score :  14.0
# episode:  episode: 51 / score :  16.0
#  52 / score :  28.0
# episode:  53 / score :  30.0
# episode: episode:  54 / score :  18.0
#  55 / score :  17.0
# episode:  56 / score :  13.0
# episode:  57 / score :  12.0
# episode:  58 / score :  47.0
# episode: episode:   60 / score :  69.0
# 59 / score :  12.0
# episode:  61episode:   / score :  19.0
# 62 / score :  27.0
# episode:  63 / score :  24.0
# episode:  64 / score :  36.0
# episode:  65 / score :  31.0
# episode:  66 / score :  11.0
# episode:  67 / score :  13.0
# episode:  68episode:   / score :  15.0
# episode: 69  70 / score :  22.0
# / score :  19.0
# episode:  71 / score :  14.0
# episode:  72 / score :  36.0
# episode:  73 / score : episode:   28.0
# 74 / score :  19.0
# episode:  75 / score :  episode: 48.0
#  76 / score :  33.0
# episode:  77 / score :  43.0
# episode: episode:  78 / score :  53.0
#  79 / score :  34.0
# episode:  80 / score :  17.0
# episode:  81 / score :  24.0
# episode:  82 / score :  46.0
# episode:  83 / score :  11.0
# episode:  episode:  85 / score :  35.0
# 84 / score :  16.0
# episode: episode:   8786 / score :  24.0
#  / score :  18.0
# episode:  88 / score :  37.0
# episode:  89 / score :  19.0
# episode:  90 / score :  43.0
# episode:  91 / score :  17.0
# episode:  92 / score :  61.0
# episode:  93 / score :  13.0
# episode:  94 / score :  28.0
# episode:  95 / score :  17.0
# episode:  96 / score :  31.0
# episode:  97 / score :  12.0
# episode:  98 / score :  48.0
# episode:  99 episode: / score :   67.0100
#  / score :  67.0
# episode: episode:   102 / score :  20.0
# 101episode:  / score :  32.0
# episode:  103 / score :   104 / score :  15.0
# 10.0
# episode:  105 / score :  11.0
# episode:  106 / score :  20.0
# episode: episode:  108 / score :  20.0
#  107 / score :  21.0
# episode: episode:  109 / score :  96.0
# 110 / score :  34.0
# episode:  111 / score :  52.0
# episode:  112 / score :  21.0
# episode: episode:  114 / score :  21.0
#  113 / score :  52.0
# episode:  115 / score :  55.0
# episode:  116 / score :  42.0
# episode:  117 / score :  18.0
# episode:  118 / score :  25.0
# episode:  119 / score :  45.0
# episode:  120 / score :  19.0
# episode:  episode: 121 / score :  122 / score :  16.0
#  11.0
# episode:  123 / score :  39.0
# episode:  124 / score :  33.0
# episode:  125 / score :  34.0
# episode:  126 / score :  54.0
# episode:  127 / score :  44.0
# episode:  128 / score :  40.0
# episode:  129 / score :  47.0
# episode:  130 / score :  95.0
# episode:  131 / score :  23.0
# episode:  132 / score :  44.0
# episode:  133 / score :  31.0
# episode: episode:   135 / score :  34.0
# 134 / score :  33.0
# episode:  136 / score :  46.0
# episode:  137 / score :  30.0
# episode:  138 episode: / score :  70.0
#  139 / score :  36.0
# episode:  140 episode:  / score :  14121.0
#  / score :  18.0
# episode:  142 / score :  56.0
# episode:  143 / score :  26.0
# episode:  144 / score :  38.0
# episode:  145 / score :  54.0
# episode: episode:   146147  / score :  27.0
# / score :  18.0
# episode:  148 / score :  44.0
# episode:  149 / score :  57.0
# episode:  150 / score :  59.0
# episode:  151 / score :  19.0
# episode:  152 / score :  94.0
# episode: episode:  154 / score :  91.0
#  153 / score :  36.0
# episode:  155 / score :  172.0
# episode:  156 / score :  126.0
# episode:  157 / score :  66.0
# episode:  158 / score :  68.0
# episode:  159 / score :  83.0
# episode:  160 / score :  45.0
# episode:  161 / score :  46.0
# episode:  162 / score :  119.0
# episode:  163 / score :  100.0
# episode:  164 / score :  33.0
# episode:  165 / score :  69.0
# episode:  166 / score :  64.0
# episode:  167 / score :  41.0
# episode:  168 / score :  147.0
# episode:  169 / score :  62.0
# episode:  170 / score :  40.0
# episode:  171 / score :  33.0
# episode:  172 / score :  196.0
# episode:  173episode:  / score :  61.0
# episode:   175 / score :  116.0
# 174 / score :  45.0
# episode:  176 / score :  153.0
# episode:  177 / score :  167.0
# episode:  178 / score :  53.0
# episode:  179 / score :  153.0
# episode: episode:  181 / score :  73.0
#  180 / score :  60.0
# episode:  182 / score :  51.0
# episode:  183 / score :  67.0
# episode:  184 / score :  71.0
# episode:  185 / score :  23.0
# episode:  186 / score :  39.0
# episode:  187 / score :  66.0
# episode:  188episode:  / score :   54.0
# 189 / score :  47.0
# episode:  190 / score :  154.0
# episode:  191 / score :  184.0
# episode:  192 / score :  152.0
# episode:  193 / score :  181.0
# episode:  194 / score :  48.0
# episode:  195 / score :  249.0
# episode:  196 / score :  173.0
# episode:  197 / score :  145.0
# episode:  198 / score :  152.0
# episode:  199 / score :  81.0
# episode:  200 / score :  126.0
# episode:  201 / score :  115.0
# episode:  202 / score :  190.0
# episode:  203 / score :  80.0
# episode:  204 / score :  150.0
# episode:  205 / score :  149.0
# episode:  206 / score :  214.0
# episode:  207 / score :  191.0
# episode:  208 / score :  112.0
# episode:  209 / score :  151.0
# episode:  210 / score :  172.0
# episode:  211 / score :  125.0
# episode:  212 / score :  222.0
# episode:  213 / score :  154.0
# episode:  214 / score :  128.0
# episode: episode:  216 / score :  169.0
#  215 / score :  126.0
# episode:  217 / score :  199.0
# episode:  218 / score :  132.0
# episode:  219 / score :  137.0
# episode:  220 / score :  466.0
# episode:  221 / score :  168.0
# episode:  222 / score :  164.0
# episode:  223 / score :  160.0
# episode:  224 / score :  75.0
# episode:  225 / score :  141.0
# episode:  226 / score :  327.0
# episode:  227 / score :  109.0
# episode:  228 / score :  157.0
# episode:  229 / score :  268.0
# episode:  230 / score :  199.0
# episode:  231 / score :  255.0
# episode:  232 / score :  336.0
# episode:  233 / score :  223.0
# episode:  234 / score :  248.0
# episode:  235 / score :  220.0
# episode:  236 / score :  109.0
# episode:  237 / score :  179.0
# episode:  238 / score :  179.0
# episode:  239 / score :  135.0
# episode:  240 / score :  183.0
# episode:  241 / score :  102.0
# episode:  242 / score :  213.0
# episode:  243 / score :  190.0
# episode:  244 / score :  309.0
# episode:  245 / score :  500.0
# episode:  246 / score :  211.0
# episode:  247 / score :  319.0
# episode:  248 / score :  379.0
# episode:  249 / score :  339.0
# episode:  250 / score :  397.0
# episode:  251 / score :  500.0
# episode:  252 / score :  364.0
# episode:  253 / score :  318.0
# episode:  254 / score :  271.0
# episode:  255 / score :  134.0
# episode:  256 / score :  313.0
# episode:  257 / score :  97.0
# episode:  258 / score :  167.0
# episode:  259 / score :  500.0
# episode:  260 / score :  342.0
# episode:  261 / score :  326.0
# episode:  262 / score :  95.0
# episode:  263 / score :  500.0
# episode:  264 / score :  334.0
# episode:  265 / score :  500.0
# episode:  266 / score :  148.0
# episode:  267 / score :  482.0
# episode:  268 / score :  193.0
# episode:  269 / score :  76.0
# episode:  270 / score :  180.0
# episode:  271 / score :  126.0
# episode:  272 / score :  320.0
# episode:  273 / score :  344.0
# episode:  274 / score :  420.0
# episode:  275 / score :  500.0
# episode:  276 / score :  402.0
# episode:  277 / score :  500.0
# episode:  278 / score :  500.0
# episode:  279 / score :  500.0
# episode:  280 / score :  96.0
# episode:  281 / score :  500.0
# episode:  282 / score :  500.0
# episode:  283 / score :  187.0
# episode:  284 / score :  342.0
# episode:  285 / score :  393.0
# episode:  286 / score :  500.0
# episode:  287 / score :  500.0
# episode:  288 / score :  500.0
# episode:  289 / score :  500.0
# episode:  290 / score :  298.0
# episode:  291 / score :  400.0
# episode:  292 / score :  463.0
# episode:  293 / score :  500.0
# episode:  294 / score :  289.0
# episode:  295 / score :  198.0
# episode:  296 / score :  364.0
# episode:  297 / score :  500.0
# episode:  298 / score :  359.0
# episode:  299 / score :  500.0
# episode:  300 / score :  419.0
# episode:  301 / score :  500.0
# episode:  302 / score :  500.0
# episode:  303 / score :  500.0
# episode:  304 / score :  326.0
# episode:  305 / score :  105.0
# episode:  306 / score :  294.0
# episode:  307 / score :  500.0
# episode:  308 / score :  363.0
# episode:  309 / score :  217.0
# episode:  310 / score :  500.0
# episode:  311 / score :  307.0
# episode:  312 / score :  500.0
# episode:  313 / score :  500.0
# episode:  314 / score :  371.0
# episode:  315 / score :  500.0
# episode:  316 / score :  500.0
# episode:  317 / score :  500.0
# episode:  318 / score :  500.0
# episode:  319 / score :  500.0
# episode:  320 / score :  456.0
# episode:  321 / score :  500.0
# episode:  322 / score :  500.0
# episode:  323 / score :  500.0
# episode:  324 / score :  448.0
# episode:  325 / score :  335.0
# episode:  326 / score :  500.0
# episode:  327 / score :  500.0
# episode:  328 / score :  444.0
# episode:  329 / score :  340.0
# episode:  330 / score :  500.0
# episode:  331 / score :  500.0
# episode:  332 / score :  500.0
# episode:  333 / score :  500.0
# episode:  334 / score :  459.0
# episode:  335 / score :  450.0
# episode:  336 / score :  491.0
# episode:  337 / score :  500.0
# episode:  338 / score :  467.0
# episode:  339 / score :  437.0
# episode:  340 / score :  253.0
# episode:  341 / score :  500.0
# episode:  342 / score :  500.0
# episode:  343 / score :  500.0
# episode:  344 / score :  500.0
# episode:  345 / score :  500.0
# episode:  346 / score :  500.0
# episode:  347 / score :  122.0
# episode:  348 / score :  500.0
# episode:  349 / score :  500.0
# episode:  350 / score :  481.0
# episode:  351 / score :  470.0
# episode:  352 / score :  500.0
# episode:  353 / score :  275.0
# episode:  354 / score :  500.0
# episode:  355 / score :  500.0
# episode:  356 / score :  500.0
# episode:  357 / score :  500.0
# episode:  358 / score :  500.0
# episode:  359 / score :  500.0
# episode:  360 / score :  500.0
# episode:  361 / score :  500.0
# episode:  362 / score :  500.0
# episode:  363 / score :  500.0
# episode:  364 / score :  500.0
# episode:  365 / score :  500.0
# episode:  366 / score :  500.0
# episode:  367 / score :  500.0
# episode: episode:  368 / score :  500.0
#  369 / score :  500.0
# episode:  370 / score :  500.0
# episode:  371 / score :  500.0
# episode:  372 / score :  500.0
# episode:  373 / score :  500.0
# episode:  374 / score :  500.0
# episode:  375 / score :  500.0
# episode:  376 / score :  467.0
# episode:  377 / score :  500.0
# episode:  378 / score :  500.0
# episode:  379 / score :  500.0
# episode:  380 / score :  500.0
# episode:  381 / score :  500.0
# episode:  382 / score :  413.0
# episode:  383 / score :  500.0
# episode:  384 / score :  447.0
# episode:  385 / score :  500.0
# episode:  386 / score :  495.0
# episode:  387 / score :  492.0
# episode:  388 / score :  500.0
# episode:  389 / score :  500.0
# episode:  390 / score :  500.0
# episode:  391 / score :  284.0
# episode:  392 / score :  313.0
# episode:  393 / score :  500.0
# episode:  394 / score :  500.0
# episode:  395 / score :  500.0
# episode:  396 / score :  500.0
# episode:  397 / score :  500.0
# episode:  398 / score :  500.0
# episode:  399 / score :  500.0
# episode:  400 / score :  500.0
# episode:  401 / score :  500.0
# episode:  402 / score :  500.0
# episode:  403 / score :  500.0
# episode:  404 / score :  500.0
# episode:  405 / score :  500.0
# episode:  406 / score :  500.0
# episode:  407 / score :  500.0
# episode:  408 / score :  500.0
# episode: episode:   410 / score :  500.0
# 409 / score :  500.0
# episode:  411 / score :  500.0
# episode:  412 / score :  500.0
# episode:  413 / score :  500.0
# episode:  414 / score :  500.0
# episode:  415 / score :  500.0
# episode:  416 / score :  500.0
# episode:  417 / score :  500.0
# episode:  418 / score :  500.0
# episode:  419 / score :  500.0
# episode:  420 / score :  403.0
# episode:  421 / score :  500.0
# episode:  422 / score :  500.0
# episode:  423 / score :  500.0
# episode:  424 / score :  500.0
# episode:  425 / score :  288.0
# episode:  426 episode: / score :  427 / score :  500.0
#  500.0
# episode:  428 / score :  500.0
# episode:  429 / score :  500.0
# episode:  430 / score :  287.0
# episode:  431 / score :  500.0
# episode:  432 / score :  500.0
# episode:  433 / score :  500.0
# episode:  434 / score :  185.0
# episode:  435 / score :  500.0
# episode:  436 / score :  500.0
# episode:  437 / score :  500.0
# episode:  438 / score :  500.0
# episode:  439 / score :  500.0
# episode:  440 / score :  500.0
# episode:  441 / score :  500.0
# episode:  442 / score :  500.0
# episode:  443 / score :  500.0
# episode:  444 / score :  500.0
# episode:  445 / score :  500.0
# episode:  446 / score :  500.0
# episode:  447 / score :  203.0
# episode:  448 / score :  454.0
# episode:  449 / score :  500.0
# episode:  450 / score :  500.0
# episode:  451 / score :  500.0
# episode:  452 / score :  500.0
# episode:  453 / score :  500.0
# episode:  454 / score :  500.0
# episode:  455 / score :  500.0
# episode:  456 / score :  450.0
# episode:  457 / score :  500.0
# episode:  458 / score :  500.0
# episode:  459 / score :  500.0
# episode:  460 / score :  500.0
# episode:  461 / score :  365.0
# episode:  462 / score :  500.0
# episode:  463 / score :  500.0
# episode:  464 / score :  449.0
# episode:  465 / score :  354.0
# episode:  466 / score :  500.0
# episode:  467 / score :  500.0
# episode:  468 / score :  500.0
# episode:  469 / score :  500.0
# episode:  470 / score :  500.0
# episode:  471 / score :  500.0
# episode:  472 / score : episode:  500.0
#  473 / score :  500.0
# episode:  474 / score :  500.0
# episode:  475 / score :  500.0
# episode:  476 / score :  500.0
# episode:  477 / score :  500.0
# episode:  478 / score :  500.0
# episode:  479 / score :  500.0
# episode:  480 / score :  500.0
# episode:  481 / score :  500.0
# episode:  482 / score :  500.0
# episode:  483 / score :  500.0
# episode:  484 / score :  472.0
# episode:  485 / score :  500.0
# episode:  486 / score :  500.0
# episode:  487 / score :  500.0
# episode:  488 / score :  500.0
# episode:  489 / score :  431.0
# episode:  490 / score :  500.0
# episode:  491 / score :  455.0
# episode:  492 / score :  193.0
# episode:  episode:  494 / score :  500.0
# 493 / score :  395.0
# episode:  495 / score :  339.0
# episode:  496 / score :  500.0
# episode:  497 / score :  410.0
# episode:  498 / score :  500.0
# episode:  499 / score :  303.0
# episode:  500 / score :  361.0
# episode:  501 / score :  470.0
# episode:  502 / score :  429.0
# episode:  503 / score :  500.0
# episode:  504 / score :  446.0
# episode:  505 / score :  444.0
# episode:  506 / score :  291.0
# episode:  507 / score :  500.0
# episode:  508 / score :  500.0
# episode:  509 / score :  500.0
# episode:  510 / score :  77.0
# episode:  511 / score :  467.0
# episode:  512 / score :  500.0
# episode:  513 / score :  500.0
# episode:  514 / score :  449.0
# episode:  515 / score :  500.0
# episode:  516 / score :  147.0
# episode:  517 / score :  500.0
# episode:  518 / score :  434.0
# episode:  519 / score :  500.0
# episode:  520 / score :  500.0
# episode:  521 / score :  443.0
# episode:  522 / score :  500.0
# episode:  523 / score :  500.0
# episode:  524 / score :  467.0
# episode:  525 / score :  424.0
# episode:  526 / score :  69.0
# episode:  527 / score :  276.0
# episode:  528 / score :  500.0
# episode:  529 / score :  235.0
# episode:  530 / score :  251.0
# episode:  531 / score :  460.0
# episode:  532 / score :  500.0
# episode:  533 / score :  500.0
# episode:  534 / score :  500.0
# episode:  535 / score :  224.0
# episode:  536 / score :  500.0
# episode:  537 / score :  500.0
# episode:  538 / score :  442.0
# episode:  539 / score :  266.0
# episode:  540 / score :  500.0
# episode:  541 / score :  500.0
# episode:  542 / score :  500.0
# episode:  543 / score :  500.0
# episode:  544 / score :  500.0
# episode:  545 / score :  500.0
# episode:  episode: 546  547/ score :  500.0
#  / score :  500.0
# episode:  548 / score :  500.0
# episode:  549 / score :  500.0
# episode:  550 / score :  500.0
# episode:  551 / score :  500.0
# episode:  552 / score :  500.0
# episode:  553 / score :  500.0
# episode:  554 / score :  500.0
# episode:  555 / score :  500.0
# episode:  556 / score :  500.0
# episode:  557 / score :  500.0
# episode:  558 / score :  500.0
# episode:  559 / score :  500.0
# episode:  560 / score :  175.0
# episode:  561 / score :  500.0
# episode:  562 / score :  500.0
# episode:  563 / score :  500.0
# episode:  564 / score :  500.0
# episode:  565 / score :  500.0
# episode:  566 / score :  500.0
# episode:  567 / score :  500.0
# episode:  568 / score :  500.0
# episode:  569 / score :  500.0
# episode:  570 / score :  212.0
# episode:  571 / score :  500.0
# episode:  572 / score :  500.0
# episode:  573 / score :  222.0
# episode:  574 / score :  500.0
# episode:  575 / score :  500.0
# episode:  576 / score :  500.0
# episode:  577 / score :  500.0
# episode:  578 / score :  500.0
# episode:  579 / score :  500.0
# episode:  580 / score :  500.0
# episode:  581 / score :  500.0
# episode:  582 / score :  500.0
# episode:  583 / score :  500.0
# episode:  584 / score :  500.0
# episode:  585 / score :  500.0
# episode:  586 / score :  500.0
# episode:  587 / score :  500.0
# episode:  588 / score :  335.0
# episode:  589 / score :  91.0
# episode:  590 / score :  500.0
# episode:  591 / score :  500.0
# episode:  592 / score :  500.0
# episode:  593 / score :  500.0
# episode:  594 / score :  500.0
# episode: episode:  595 / score :  500.0
#  596 / score :  500.0
# episode:  597 / score :  500.0
# episode:  598 / score :  500.0
# episode:  599 / score :  500.0
# episode:  600 / score :  500.0
# episode:  601 / score :  375.0
# episode:  602 / score :  444.0
# episode:  603 / score :  500.0
# episode:  604 / score :  500.0
# episode:  605 / score :  500.0
# episode:  606 / score :  500.0
# episode:  607 / score :  500.0
# episode:  608 / score :  500.0
# episode:  609 / score :  500.0
# episode:  610 / score :  500.0
# episode:  611 / score :  500.0
# episode:  612 / score :  500.0
# episode:  613 / score :  500.0
# episode:  614 / score :  500.0
# episode:  615 / score :  500.0
# episode:  616 / score :  500.0
# episode:  617 / score :  500.0
# episode:  618 / score :  500.0
# episode:  619 / score :  500.0
# episode:  620 / score :  500.0
# episode:  621 / score :  500.0
# episode:  622 / score :  500.0
# episode:  623 / score :  500.0
# episode:  624 / score :  500.0
# episode:  625 / score :  500.0
# episode:  626 / score :  500.0
# episode:  627 / score :  500.0
# episode:  628 / score :  500.0
# episode:  629 / score :  500.0
# episode:  630 / score :  500.0
# episode:  631 / score :  379.0
# episode:  632 / score :  500.0
# episode:  633 / score :  500.0
# episode:  634 / score :  500.0
# episode:  635 / score :  500.0
# episode:  636 / score :  500.0
# episode:  637 / score :  500.0
# episode:  638 / score :  500.0
# episode:  639 / score :  500.0
# episode:  640 / score :  500.0
# episode:  641 / score :  463.0
# episode:  642 / score :  500.0
# episode:  643 / score :  500.0
# episode:  644 / score :  500.0
# episode:  645 / score :  500.0
# episode:  646 / score :  500.0
# episode:  647 / score :  500.0
# episode:  648 / score :  500.0
# episode:  649 / score :  500.0
# episode:  650 / score :  500.0
# episode:  651 / score :  500.0
# episode:  652 / score :  500.0
# episode:  653 / score :  500.0
# episode:  654 / score :  500.0
# episode:  655 / score :  500.0
# episode:  656 / score :  500.0
# episode:  657 / score :  500.0
# episode:  658 / score :  500.0
# episode:  659 / score :  500.0
# episode:  660 / score :  500.0
# episode:  661 / score :  500.0
# episode:  662 / score :  500.0
# episode:  663episode:   / score :  664500.0 / score :  500.0
#
# episode:  665 / score :  500.0
# episode:  666 / score :  500.0
# episode:  667 / score :  500.0
# episode:  668 / score :  356.0
# episode:  669 / score :  500.0
# episode:  670 / score :  500.0
# episode:  671 / score :  500.0
# episode:  672 / score :  500.0
# episode:  673 / score :  500.0
# episode:  674 / score :  500.0
# episode:  675 / score :  500.0
# episode:  676 / score :  500.0
# episode:  677 / score :  500.0
# episode:  678 / score :  500.0
# episode:  679 / score :  500.0
# episode:  680 / score :  500.0
# episode:  681 / score :  500.0
# episode:  682 / score :  500.0
# episode:  683 / score :  500.0
# episode:  684 / score :  500.0
# episode:  685 / score :  500.0
# episode:  686 / score :  500.0
# episode:  687 / score :  500.0
# episode:  688 / score :  500.0
# episode:  689 / score :  500.0
# episode:  690 / score :  500.0
# episode:  691 / score :  500.0
# episode:  692 / score :  500.0
# episode:  693 / score :  500.0
# episode:  694 / score :  500.0
# episode:  695 / score :  500.0
# episode:  696 / score :  500.0
# episode:  697 / score :  500.0
# episode:  698 / score :  500.0
# episode:  699 / score :  500.0
# episode:  700 / score :  500.0
# episode:  701 / score :  500.0
# episode:  702 / score :  500.0
# episode:  703 / score :  episode: 500.0 704
#  / score :  500.0
# episode:  705 / score :  500.0
# episode:  706 / score :  500.0
# episode:  707 / score :  500.0
# episode:  708 / score :  500.0
# episode:  709 / score :  500.0
# episode:  710 / score :  500.0
# episode:  711 / score :  500.0
# episode:  712 / score :  500.0
# episode:  713 / score :  500.0
# episode:  714 / score :  500.0
# episode:  715 / score :  500.0
# episode:  716 / score :  500.0
# episode:  717 / score :  500.0
# episode:  718 / score :  500.0
# episode:  719 / score :  500.0
# episode:  720 / score :  500.0
# episode:  721 / score :  500.0
# episode:  722 / score :  500.0
# episode:  723 / score :  500.0
# episode:  724 / score :  500.0
# episode:  725 / score :  500.0
# episode:  726 / score :  500.0
# episode:  727 / score :  500.0
# episode:  728 / score :  500.0
# episode:  729 / score :  500.0
# episode:  730 / score :  500.0
# episode:  731 / score :  500.0
# episode:  732 / score :  500.0
# episode:  733 / score :  500.0
# episode:  734 / score :  500.0
# episode:  735 / score :  500.0
# episode:  736 episode: / score :  500.0
#  737 / score :  500.0
# episode:  738 / score :  500.0
# episode:  739 / score :  500.0
# episode:  740 / score :  500.0
# episode:  741 / score :  427.0
# episode:  742 / score :  500.0
# episode:  743 / score :  500.0
# episode:  744 / score :  500.0
# episode:  745 / score :  500.0
# episode:  746 / score :  500.0
# episode:  747 / score :  500.0
# episode:  748 / score :  500.0
# episode:  749 / score :  500.0
# episode:  750 / score :  500.0
# episode:  751 / score :  500.0
# episode:  752 / score :  500.0
# episode:  753 / score :  500.0
# episode:  754 / score :  500.0
# episode:  755 / score :  500.0
# episode:  756 / score :  500.0
# episode:  757 / score :  209.0
# episode:  758 / score :  500.0
# episode:  759 / score :  500.0
# episode:  760 / score :  500.0
# episode:  761 / score :  500.0
# episode:  762 / score :  294.0
# episode:  763 / score :  329.0
# episode:  764 / score :  500.0
# episode:  765 / score :  500.0
# episode:  766 / score :  137.0
# episode:  767 / score :  309.0
# episode:  768 / score :  165.0
# episode:  769 / score :  312.0
# episode:  770 / score :  143.0
# episode:  771 / score :  155.0
# episode:  772 / score :  148.0
# episode:  773 / score :  48.0
# episode:  774 / score :  106.0
# episode:  775 / score :  116.0
# episode:  776 / score :  111.0
# episode:  777 / score :  78.0
# episode:  778 / score :  50.0
# episode:  779 / score :  24.0
# episode:  780 / score :  49.0
# episode:  781 / score :  109.0
# episode:  782 / score :  26.0
# episode:  783 / score :  21.0
# episode:  784 / score :  23.0
# episode:  785 / score :  26.0
# episode:  786 / score :  16.0
# episode:  episode:  788 / score :  26.0
# 787 / score :  episode: 40.0 789 / score :  23.0
# episode:  episode: 790 / score :  24.0
#
#  791 / score :  17.0
# episode:  792episode:  / score :  18.0
#  793 / score :  20.0
# episode:  794 / score :  21.0
# episode:  795 / score :  19.0
# episode:  796 / score :  18.0
# episode:  797 / score :  18.0
# episode: episode: episode:   800 / score :  22.0
#  798episode:  / score :  20.0
#  801 / score :  22.0
# 799episode:   802/ score :  21.0
#  / score :  21.0
# episode:  803 / score :  25.0
# episode:  804 / score :  23.0
# episode:  805 / score :  15.0
# episode: episode:   806 / score :  21.0
# 807 / score :  24.0
# episode: episode:  809 808 / score :  20.0
#  / score :  24.0
# episode:  810 / score :  17.0
# episode:  811 / score :  21.0
# episode:  812 / score :  23.0
# episode:  813 / score :  19.0
# episode:  814 / score :  18.0
# episode:  815 / score :  18.0
# episode:  816 / score :  20.0
# episode:  817 / score :  20.0
# episode:  818 / score :  23.0
# episode:  819 / score :  28.0
# episode: episode: episode:  820 / score :  23.0
#  821 / score :  22.0
# episode:  823 / score :  20.0
#  822 / score :  23.0
# episode:  episode: 824 / score :  19.0
#  825 / score :  22.0
# episode:  826 / score :  24.0
# episode: episode:  828 / score :  19.0
#  827episode:  829 / score :  19.0
# episode:  / score :  830 / score :  19.0
#  21.0
# episode:  831 / score :  28.0
# episode:  832 / score :  18.0
# episode:  833 / score :  20.0
# episode:  834episode:  835 / score :  19.0
#  / score :  19.0
# episode:  836 / score :  19.0
# episode:  837episode:  / score :  15.0
#  838 / score :  21.0
# episode:  839 / score :  17.0
# episode:  840 / score :  22.0
# episode:  841 / score :  22.0
# episode:  842 / score :  17.0
# episode:  843 / score :  19.0
# episode:  844 / score :  23.0
# episode:  845 episode: / score :  20.0
#  episode: episode: 846 / score :  20.0
#  847 / score :  16.0
#  848episode: episode:  850 / score :  22.0
#  / score :  849 / score :  27.0
#  22.0
# episode:  851 / score :  24.0
# episode:  852episode:  / score :   19.0episode: episode:
# 853episode:  855 / score :  20.0
#  / score :  18.0
#   854episode: episode:  / score :  21.0
#  857 / score :  20.0
# 856 / score :  23.0
#  858 / score :  26.0
# episode:  859 / score :  28.0
# episode: episode:  episode: 861 / score :  15.0
#   862 / score :  18.0
# 860 / score :  17.0
# episode:  863 / score :  17.0
# episode:  864 / score :  17.0
# episode:  865 / score :  22.0
# episode:  episode: 866 867 / score :  24.0
#  / score :  24.0
# episode:  868 / score :  18.0
# episode: episode:  869 / score :  26.0
# episode: episode:  871 / score :  25.0
#  870  / score :  15.0
# 872 / score :  13.0
# episode:  873 / score :  24.0
# episode:  874 / score :  20.0
# episode:  875 / score :  36.0
# episode: episode:  episode: 877 / score :  13.0
#  878 / score :  19.0
#  876episode:  879 / score :  14.0
#  / score :  15.0
# episode:  880 / score :  25.0
# episode:  881 / score :  20.0
# episode:  882 / score :  18.0
# episode:  883 / score :  27.0
# episode:  884 / score :  17.0
# episode:  885 / score :  16.0
# episode:  886 / score :  11.0
# episode:  episode:  888 / score :  15.0
# 887 / score :  24.0
# episode:  889 / score :  30.0
# episode:  890 / score :  25.0
# episode:  891 / score :  23.0
# episode: episode:  893 / score :  28.0
#  892 / score :  22.0
# episode:  894 / score :  20.0
# episode:  895 / score :  15.0
# episode:  896 / score :  29.0
# episode:  897 / score :  21.0
# episode:  898 / score :  22.0
# episode:  899 / score :  27.0
# episode:  900 / score :  17.0
# episode:  901 / score :  20.0
# episode:  902 / score :  19.0
# episode:  903 / score :  16.0
# episode:  904 / score :  23.0
# episode: episode:   905 / score :  21.0
# episode: episode:  907 / score :  18.0
#  906908 / score :  20.0
#  / score :  19.0
# episode: episode:  episode:   911 / score :  24.0
# 909 910/ score :   / score : 22.0
#  30.0
# episode:  912 / score :  27.0
# episode:  913 / score :  13.0
# episode:  914 / score :  19.0
# episode:  915 / score :  16.0
# episode:  916 / score :  22.0
# episode:  917 / score :  20.0
# episode:  918 / score :  21.0
# episode:  919 / score :  23.0
# episode:  920 / score :  15.0
# episode: episode:   922 / score :  20.0
# episode: 921 / score :  20.0
# episode:  923 / score :  23.0
# episode:  925 / score :  26.0
# episode:  926 / score :  20.0
# episode:  927 / score :  27.0
#  924 / score :  25.0
# episode:  episode:  929 / score :  24.0
# 928 / score :  14.0
# episode: episode:  931 / score :  22.0
#  930 / score :  24.0
# episode:  932 / score :  21.0
# episode: episode:  933 / score :  27.0
#  episode: 934  935 / score :  25.0
# / score :  23.0
# episode:  936 / score :  16.0
# episode: episode: episode:   938937 / score :  21.0
#   / score :  20.0
# 939episode:  940  / score :  29.0
# / score :  23.0
# episode:  941 / score :  25.0
# episode: episode:  942 / score :  24.0
#  943 / score :  26.0
# episode:  944 / score :  24.0
# episode: episode:  946 / score :  16.0
#  945 / score :  17.0
# episode: episode:   948947 / score :  20.0
#  episode: / score :  949 / score :  26.0
#  23.0
# episode:  950 / score :  28.0
# episode:  951 / score :  27.0
# episode:  952 / score :  17.0
# episode: episode:   954 / score :  22.0
# 953 / score :  19.0
# episode:  episode: 955 956 / score :  24.0
# episode:   957 / score :  20.0
# / score :  21.0
# episode:  episode: 958 / score :  26.0
#  959 / score :  20.0
# episode:  960 / score :  29.0
# episode:  961 / score :  21.0
# episode:  962 / score : episode:  episode:  22.0
#  episode: 964 / score :  22.0
#  963965 episode:  / score :  25.0
#  / score :  20.0
# 966 / score :  22.0
# episode:  967 / score :  24.0
# episode:  968 / score :  24.0
# episode:  969 / score :  13.0
# episode:  970 / score :  12.0
# episode:  971 / score :  19.0
# episode:  972 / score :  25.0
# episode: episode: episode:  974 / score :  23.0
#   973975 / score :  28.0
# episode:  / score :  22.0
#  976 / score :  30.0
# episode:  977 / score :  28.0
# episode:  978 / score :  18.0
# episode:  979 / score :  29.0
# episode:  980 / score :  17.0
# episode: episode:  982 / score :  24.0
#  981 / score :  18.0
# episode: episode:  984 / score :  22.0
#  983 / score :  19.0
# episode:  985 / score :  18.0
# episode:  986 / score :  23.0
# episode:  987 / score :  23.0
# episode:  988 / score :  23.0
# episode:  989 / score :  26.0
# episode:  990 / score :  18.0
# episode:  991 / score :  25.0
# episode:  992 / score :  22.0
# episode: episode:  994 / score :  25.0
#  993 / score :  23.0
# episode:  995 / score :  28.0
# episode:  996 / score :  24.0
# episode:  997 / score :  18.0
# episode: episode:  998 / score :  21.0
#  999 / score :  18.0
# episode:  1000 / score :  25.0
# episode:  1001 / score :  24.0
# episode:  1002 / score :  28.0
# episode:  1003 / score :  27.0
# episode:  1004 / score :  32.0
# episode:  1005 / score :  22.0
# episode:  episode:  10071006 / score :  26.0
#  episode:  1008 / score :  28.0
# / score :  21.0
# episode:  1009 / score :  22.0
# episode:  1010episode: episode:  / score :  33.0
#  1011 / score :  28.0
#  1012 / score :  27.0
# episode:  1013episode:  / score :   1014 / score :  17.0
# 16.0
# episode:  1015 / score :  26.0
# episode:  1016 / score :  19.0
# episode:  episode:  10171018 / score :  21.0
#  / score :  24.0
# episode:  1019 / score :  27.0
# episode:  1020 / score :  27.0
# episode:  1021 / score :  19.0
# episode:  1022 / score :  26.0
# episode:  1023 / score :  32.0
# episode:  1024 / score :  23.0
# episode:  1025 / score :  23.0
# episode:  1026 / score :  15.0
# episode:  1027 / score :  21.0
# episode:  1028 / score :  25.0
# episode:  1029 / score :  30.0
# episode:  1030 / score :  11.0
# episode: episode: episode:  1032 / score :  12.0
#  1031 / score :  16.0
#  1033 / score :  19.0
# episode:  1034 / score :  34.0
# episode:  1035 / score :  22.0
# episode:  1036 / score :  29.0
# episode:  1037 / score :  24.0
# episode:  1038 / score :  19.0
# episode:  1039 / score :  28.0
# episode:  episode:  1041 / score :  28.0
# 1040 / score :  23.0
# episode:  1042 / score :  27.0
# episode:  1043 / score :  25.0
# episode:  episode: 1044  / score :  20.0
# 1045 / score :  15.0
# episode:  1046 / score :  16.0
# episode:  1047 / score :  16.0
# episode:  1048 / score :  25.0
# episode:  1049 / score :  17.0
# episode:  1050 / score :  17.0
# episode:  episode:  1051 / score :  19.0
# episode: 1052 1053 / score :  27.0
# episode:   1054 / score :  30.0
# episode: / score : episode:  1055 / score :  22.0
#  29.0
#  1056 / score :  27.0
# episode:  1057 / score :  31.0
# episode:  episode: 1058 / score :  22.0
#  1059 / score :  19.0
# episode:  1060 / score :  20.0
# episode:  1061 / score :  19.0
# episode:  1062 / score :  23.0
# episode:  1063 / score :  26.0
# episode:  1064 / score :  24.0
# episode:  1065 / score :  28.0
# episode:  1066 / score :  15.0
# episode:  1067 / score :  15.0
# episode:  1068 / score :  18.0
# episode: episode:   episode: 1069 / score :  21.0
# 1070 1071 / score :  22.0
#  / score :  17.0
# episode:  1072 / score :  24.0
# episode:  1073 / score :  27.0
# episode:  1074 / score :  25.0
# episode:  1075 / score :  15.0
# episode:  1076 episode:  / score : 1077 24.0
#  / score :  21.0
# episode:  1078 episode: / score :  21.0
#  1079episode:   / score :  26.0
# 1080 episode:  / score : 1081 / score :  19.0
#  23.0
# episode:  1082 / score :  15.0
# episode:  1083 / score :  28.0
# episode: episode:  1084 / score :  25.0
#  1085 / score :  12.0
# episode:  1086 / score :  22.0
# episode:  1087 / score :  21.0
# episode:  1088 / score :  19.0
# episode:  1089 / score :  31.0
# episode:  1090 / score :  32.0
# episode:  episode: 1091  / score : 1092episode:  1093   / score :  19.0
# / score : 21.0
#  20.0
# episode: episode: episode:  1096 / score :  25.0
#   10941095 / score :  23.0
#  / score :  28.0
# episode: episode:  1097 / score :  20.0
#  1098 / score :  24.0
# episode:  1099 / score :  22.0
# episode:  episode:  1101 / score :  16.0
# 1100 / score :  24.0
# episode: episode:  1102 / score :  15.0
#  1103 / score :  27.0
# episode:  1104 / score :  22.0
# episode:  1105 / score :  26.0
# episode:  1106 / score :  33.0
# episode: episode:   1108 / score :  11.0
# 1107 / score :  26.0
# episode:  1109 / score :  18.0
# episode: episode:  1111 / score :  18.0
#  1110 / score :  episode: episode: episode:  1112 / score :  23.0
#  1113 / score :  23.0
#  1114 / score :  27.0
# 24.0
# episode:  1115 / score :  26.0
# episode: episode:   1117 / score :  21.0
# 1116episode:  / score :  22.0
#  1118 / score :  24.0
# episode:  1119 / score :  21.0
# episode:  episode: 1120 / score :  20.0
#  1121 / score :  22.0
# episode:  1122 / score :  28.0
# episode:  1123 episode:  episode: 1124 / score :  19.0
# / score : episode:  20.0
#   1126 / score :  25.0
# 1125episode: episode:  / score :  20.0
#  1127 / score :  20.0
#  1128 / score :  episode: 21.0
#  1129 / score :  25.0
# episode:  1130 / score :  35.0
# episode:  1131 / score :  19.0
# episode:  episode:  1133 / score :  19.0
# episode: 1132 1134 / score :  23.0
#  / score :  22.0
# episode:  1135episode:  / score :  26.0
#  1136 / score :  25.0
# episode:  1137episode:  / score :  19.0
#  1138 / score :  25.0
# episode:  1139 / score :  19.0
# episode:  episode:  1141 / score :  18.0
# episode: 1140  / score :  15.0
# episode: 1142episode:  / score :  25.0
# episode:  1144  / score :  23.0
#  1143 / score :  23.0
# 1145 / score :  21.0
# episode:  1146 / score :  30.0
# episode:  1147 / score :  24.0
# episode:  1148episode:  1149episode:   / score :  20.0
# / score :  17.0
#  episode:  1150 / score :  24.0
# 1151 / score :  22.0
# episode:  1152 / score :  23.0
# episode: episode:  1154 1153 / score :  23.0
#  / score :  28.0
# episode: episode: episode:    1157 / score :  19.0
# 1156 / score :  20.0
# 1155 / score :  18.0
# episode:  1158 / score :  28.0
# episode:  1159 / score :  22.0
# episode:  1160 / score :  29.0
# episode:  1161 / score :  28.0
# episode:  1162 / score :  29.0
# episode:  1163 / score :  21.0
# episode:  1164 / score :  22.0
# episode: episode:   1166 / score :  1165 / score :  21.0
# episode: 23.0episode:  episode: 1167 / score :  24.0
#
#  1169 / score :  26.0
# 1168 / score :  28.0
# episode:  1170 / score :  28.0
# episode:  1171 / score :  23.0
# episode: episode:  1173 / score :  17.0
#  1172 / score :  17.0
# episode:  1174 / score :  19.0
# episode:  episode: 1175 / score :  24.0
#  1176 episode: / score :  1177 / score :  22.0
#  episode: 24.0
#  1178 / score :  28.0
# episode:  1179 / score :  22.0
# episode:  1180 / score :  19.0
# episode:  episode:  1182 / score :  19.0
# 1181episode:  / score : episode:   1184 / score :  23.0
#  22.0
# 1183 / score :  16.0
# episode:  1185 / score :  21.0
# episode:  1186 / score :  32.0
# episode:  1187 / score :  18.0
# episode:  1188 episode:  1189 / score :  23.0
# / score :  22.0
# episode:  1190 / score :  24.0
# episode:  1191 / score :  30.0
# episode:  1192 / score :  27.0
# episode:  1193 / score :  27.0
# episode:  1194 / score :  32.0
# episode:  1195 episode: / score :   22.0
# 1196 / score :  17.0
# episode:  1197 / score :  27.0
# episode: episode:  1199 / score :  21.0
#  1198 / score :  18.0
# episode:  1200 episode: episode:  1201 / score :  23.0
#  / score :  120231.0 / score :  31.0
#
# episode: episode:  1204 / score :  25.0
#  1203 / score :  22.0
# episode:  1205 / score :  19.0
# episode: episode:   12071206episode:  1208 / score :  30.0
#  / score :   25.0
# / score :  16.0
# episode:  episode:  12091210 / score :  15.0
# episode:  / score :  26.0
#  1211 / score :  23.0
# episode:  1212 / score :  27.0
# episode:  1213 / score :  23.0
# episode:  1214 / score :  22.0
# episode:  episode:  1216 / score :  27.0
# 1215episode:   1217episode:  / score :  28.0
#  1218 / score :  18.0
# / score :  20.0
# episode:  1219 / score :  17.0
# episode:  1220 / score :  20.0
# episode:  1221 / score :  32.0
# episode:  1222 / score :  22.0
# episode:  1223 / score :  18.0
# episode:  episode: 1224 / score :  34.0
#  1225 / score :  20.0
# episode:  1226 / score :  28.0
# episode:  1227 / score :  30.0
# episode:  1228episode:  / score :  33.0
#  1229 / score :  13.0
# episode: episode:  1230 / score :  23.0
#  1231 / score :  24.0
# episode:  1232 / score :  32.0
# episode:  1233 / score :  14.0
# episode:  1234 / score :  22.0
# episode:  episode: 1235  / score :  1236episode:   1237 / score :  35.0
# episode: / score :  25.0
#  37.0episode:  1239 / score :  27.0
# 1238
#  / score :  23.0
# episode:  1240 / score :  29.0
# episode:  1241 / score :  29.0
# episode:  1242 / score :  21.0
# episode:  1243 / score :  15.0
# episode:  episode: episode:   12441245 / score :  14.0
# 1246 / score :  19.0
#  / score :  17.0
# episode:  1247 / score :  20.0
# episode:  1248 / score :  28.0
# episode:  1249 / score :  24.0
# episode:  1250 / score :  27.0
# episode:  episode:  12511252 / score :  27.0
#  / score :  21.0
# episode:  1253 / score :  15.0
# episode:  1254 / score :  23.0
# episode:  1255episode:   / score :  30.0
# 1256 / score :  25.0
# episode:  1257 / score :  22.0
# episode:  1258 / score :  37.0
# episode:  1259 / score :  24.0
# episode:  1260 episode: / score :  26.0
#  1261 / score :  21.0
# episode:  1262 / score :  22.0
# episode:  episode: 1263  / score :  29.0
# 1264 / score :  31.0
# episode:  1265 / score :  30.0
# episode:  1266 / score :  24.0
# episode:  1267 / score :  24.0
# episode:  episode: 1268 / score :  27.0
#  episode: 1269 / score :  16.0
#  1270 / score :  24.0
# episode:  1271 / score :  13.0
# episode:  1272 / score :  12.0
# episode:  1273 / score :  21.0
# episode:  1274 / score :  22.0
# episode:  1275 / score :  14.0
# episode:  1276 / score :  22.0
# episode:  1277 / score :  23.0
# episode: episode:  1278 / score :  17.0
#  1279 / score :  25.0
# episode:  1280 / score : episode:   128125.0 / score :  30.0
#
# episode: episode:  1283 / score :  17.0
#  1282 / score :  22.0
# episode:  1284 / score :  24.0
# episode: episode: episode:  1286 / score :  27.0
#  1287 / score :  25.0
#  1285 / score :  32.0
# episode:  1288 / score :  16.0
# episode: episode:  1290 / score :  19.0
#  1289 / score :  24.0
# episode:  1291 / score :  28.0
# episode: episode:  1292 / score :  17.0
#  1293 / score :  25.0
# episode:  1294 / score :  19.0
# episode:  1295 episode:  1296/ score :  / score :  22.0
#  19.0
# episode:  1297 / score :  22.0
# episode:  1298 / score :  15.0
# episode:  1299 / score :  13.0
# episode:  1300 / score :  19.0
# episode:  1301 / score :  22.0
# episode: episode:  1303 / score :  26.0
#  episode: 1302 / score :  19.0
#  1304 episode:  1305 / score :  30.0
# / score :  episode: 26.0
#  1306 / score :  32.0
# episode:  1307 / score :  17.0
# episode:  1308 / score :  13.0
# episode:  1309 / score :  19.0
# episode:  1310 / score :  32.0
# episode:  1311 / score :  22.0
# episode:  1312 / score :  25.0
# episode:  episode: 1313 / score :  16.0
#  1314 / score :  27.0
# episode:  1315 / score :  33.0
# episode:  1316 / score :  17.0
# episode:  1317 / score :  18.0
# episode:  1318 / score :  22.0
# episode: episode:  1319  / score :  22.0
# 1320 / score :  25.0
# episode: episode: episode:   1322 / score : episode:  31.0
#  1323 / score :  37.0
#  13211324 / score :  27.0
#  / score :  29.0
# episode:  1325 / score :  20.0
# episode:  1326 / score :  18.0
# episode:  1327 / score :  episode:  132821.0
# / score :  21.0
# episode:  1329 / score :  22.0
# episode:  1330 / score :  32.0
# episode:  episode: 1331 / score :  32.0
#  1332 / score :  27.0
# episode:  1333 / score :  27.0
# episode:  episode:  1335 / score :  17.0
# 1334 / score :  29.0
# episode: episode:   1337 / score :  27.0
# 1336 / score :  28.0
# episode:  1338 / score :  14.0
# episode:  1339 / score :  18.0
# episode:  1340 / score :  20.0
# episode:  1341 / score :  24.0
# episode: episode:  episode: 1342 / score :  20.0
# episode:  1343 / score :  28.0
#   1345 / score :  22.0
# 1344 / score :  24.0
# episode: episode:  1347 / score :  28.0
#  1346 / score :  30.0
# episode:  1348 / score :  25.0
# episode: episode: episode:  1349 / score :  19.0
# episode:  1351 / score :  17.0
#  1352 / score :  23.0
#  1350 / score :  18.0
# episode:  1353 / score :  20.0
# episode:  1354 / score :  26.0
# episode: episode:  1355 / score :  20.0
#  1356 / score :  24.0
# episode:  1357 / score :  18.0
# episode:  1358 / score :  21.0
# episode:  1359 / score :  23.0
# episode: episode:  1360 / score :  23.0
#  1361 / score :  24.0
# episode:  1362 / score :  29.0
# episode:  1363 / score :  28.0
# episode:  1364 / score :  33.0
# episode:  1365 / score :  15.0
# episode: episode:  1366 / score :  23.0
#  1367 / score :  19.0
# episode:  1368 / score :  30.0
# episode:  1369 / score :  25.0
# episode:  1370 / score :  29.0
# episode:  1371 / score :  33.0
# episode:  1372 / score :  23.0
# episode:  1373 / score :  33.0
# episode:  1374 / score :  26.0
# episode:  episode:  1376 / score :  31.0
# 1375 / score :  20.0
# episode:  episode: 1377 / score :  23.0
#  1378 / score :  27.0
# episode:  1379 / score :  27.0
# episode:  1380 / score :  27.0
# episode:  1381 / score :  18.0
# episode:  1382 / score :  21.0
# episode:  1383 / score :  23.0
# episode: episode:  1384 / score :  26.0
# episode:  episode:  1385  1386/ score :  1387 / score :  27.0
# 28.0
#  / score :  18.0
# episode:  1388 / score :  31.0
# episode:  1389 / score :  27.0
# episode:  1390 / score :  23.0
# episode:  1391 / score :  12.0
# episode:  1392 / score :  21.0
# episode:  1393 / score :  19.0
# episode:  1394 / score :  24.0
# episode:  1395episode:  1396 / score :  30.0
#  / score :  24.0
# episode:  1397 / score :  23.0
# episode:  1398 / score :  28.0
# episode:  1399 / score :  22.0
# episode: episode:  1401 / score :  24.0
#  1400 / score :  19.0
# episode:  1402 / score :  20.0
# episode:  1403 / score :  14.0
# episode:  1404 / score :  17.0
# episode:  1405 / score :  27.0
# episode:  1406 / score :  26.0
# episode:  1407 / score :  11.0
# episode:  1408 / score :  21.0
# episode:  1409 / score :  17.0
# episode:  1410 / score : episode:  16.0episode:
# 1411 / score :  20.0
#  1412 / score :  18.0
# episode:  1413 / score :  25.0
# episode:  1414 / score :  27.0
# episode:  1415 / score :  22.0
# episode:  1416 / score :  22.0
# episode: episode:   14181417 episode:  / score :  / score :   25.0
# episode:  1420 / score :  20.0
# 25.0
# 1419episode:   / score : 1421 / score :  22.0
#  28.0
# episode:  1422 / score :  30.0
# episode:  1423 / score :  13.0
# episode:  1424 / score :  30.0
# episode:  episode: 1425episode:  / score :  23.0
#  1427  / score : 1426 20.0
#  / score :  14.0
# episode:  1428 / score :  19.0
# episode:  1429 / score :  23.0
# episode: episode:  1430 / score :  22.0
#  1431 / score :  19.0
# episode:  1432 / score :  27.0
# episode:  1433 / score :  16.0
# episode:  episode: 1434 1435 / score :  22.0
#  episode: / score :  21.0
#  1436 / score :  26.0
# episode:  1437 / score :  24.0
# episode:  1438 / score :  26.0
# episode:  1439 / score :  30.0
# episode:  1440 / score :  29.0
# episode:  1441 / score :  25.0
# episode:  1442 / score :  24.0
# episode:  1443 / score :  22.0
# episode:  1444 / score :  22.0
# episode:  1445 / score :  27.0
# episode:  1446episode:   episode:  1448 / score :  28.0
# / score :  25.0
# 1447 / score :  32.0
# episode:  1449 / score :  15.0
# episode:  episode:  1451 / score :  23.0
# 1450 / score :  23.0
# episode: episode:   1453 / score :  22.0
# episode:  1454 / score :  27.0
# 1452 / score :  24.0
# episode:  1455 / score :  26.0
# episode:  1456 / score :  26.0
# episode:  1457 / score :  33.0
# episode:  1458 / score :  13.0
# episode:  1459 / score :  21.0
# episode:  1460 / score :  21.0
# episode:  1461 / score : episode:   1462 / score :  25.0
# episode: episode:  146323.0 / score :
#   28.0
# episode: 1464 / score :  25.0
#  1465 / score :  25.0
# episode:  1466 / score :  22.0
# episode:  1467 / score :  23.0
# episode:  1468 / score :  18.0
# episode:  episode:  1469 / score :  22.0
# 1470 / score :  13.0
# episode:  1471 / score :  17.0
# episode:  1472 / score :  24.0
# episode:  1473 / score :  25.0
# episode:  1474 / score :  23.0
# episode:  1475 / score :  17.0
# episode:  episode: 1476 1477 / score :  19.0
# episode:   episode: / score :  1479 / score :  14.0
# 1478 / score :  26.0
#  28.0
# episode:  1480 / score :  24.0
# episode:  1481 / score :  24.0
# episode:  1482 / score :  22.0
# episode: episode:  1483 / score :  12.0
# episode:  1485 / score :  17.0
#  1484 / score :  24.0
# episode:  1486 / score :  25.0
# episode:  1487 / score :  30.0
# episode:  1488 / score :  24.0
# episode:  1489 / score :  31.0
# ...
# 1501 / score :  24.0
# 1503 / score :  31.0
# episode:  1504 / score :  21.0
# episode:  1505 / score :  29.0
# episode:  1506episode: episode:   / score :  24.0
# 1508 / score :  36.0
#  1507 / score :  29.0
# episode:  1509 / score :  24.0
# episode:  1510 / score :  21.0
# episode: episode:  1511 episode: 1512 / score :  23.0
#  1513 / score :  20.0
#  / score :  31.0
# episode:  1514 / score :  24.0
# episode: episode:  1515 / score :  13.0
#  1516 episode:  1517 / score :  26.0
# / score :  22.0
# episode:  1518 / score :  28.0
# episode:  1519 / score :  26.0
# episode:  episode: 1520 / score :  25.0
#  1521 / score :  16.0
# episode:  episode: 1522 1523 / score :  22.0
#  / score :  23.0
# episode:  1524 / score :  29.0
# episode:  1525 / score :  28.0
# episode:  1526 / score :  26.0
# episode:  1527 / score :  31.0
# episode:  1528 / score :  23.0
# episode: episode:  1529 / score : episode:   20.0
#  15311530 / score :  23.0
#  / score :  31.0
# episode:  1532 / score :  25.0
# episode:  1533 / score :  32.0
# episode:  1534 / score :  27.0
# episode:  1535 / score :  24.0
# episode:  1536 / score :  22.0
# episode: episode:   1538 / score :  25.0
# episode:  15371539 / score :  32.0
# episode:  / score :  17.0
#  1540 / score :  26.0
# episode:  1541 / score :  37.0
# episode:  1542 / score :  20.0
# episode:  1543 / score :  13.0
# episode:  1544 episode:  1545 / score :  23.0
# episode:  1546 / score :  24.0
# episode:  episode: 1547 / score :  24.0
#  / score : 1548 / score :  23.0
#  25.0
# episode:  1549 / score :  30.0
# episode:  1550 / score :  35.0
# episode:  1551 / score :  23.0
# episode:  1552 / score :  12.0
# episode: episode:   15541553 / score :  19.0
#  / score :  23.0
# episode:  1555 / score :  27.0
# episode:  1556 / score :  33.0
# episode:  episode: 1557 1558 / score :  32.0
#  / score :  20.0
# episode:  episode:  1559 1560/ score :  25.0
#  / score :  27.0
# episode:  1561 / score :  20.0
# episode:  1562 / score :  17.0
# episode:  1563 / score :  19.0
# episode:  1564 / score :  20.0
# episode: episode:  1566 / score :  24.0
#  1565 / score :  23.0
# episode:  1567 / score :  22.0
# episode:  1568 / score :  29.0
# episode:  1569 / score :  23.0
# episode:  1570 / score :  25.0
# episode:  1571 / score :  28.0
# episode:  1572 episode: / score :   1573 / score :  19.0
# 28.0episode:
#  1574episode:  / score :  21.0
#  1575 / score :  29.0
# episode:  1576 / score :  24.0
# episode: episode:  1577 / score :  19.0
#  1578 / score :  30.0
# episode:  1579 / score :  episode:  1580 / score :  19.0
# 25.0
# episode:  1581 / score :  22.0
# episode:  1582 / score :  15.0
# episode:  1583 / score :  27.0
# episode:  1584 / score :  28.0
# episode:  1585 / score :  14.0
# episode:  1586 / score :  22.0
# episode:  1587 / score :  27.0
# episode:  1588 episode:  1589 / score :  22.0
# / score :  30.0
# episode: episode: episode:  1591 / score :  21.0
#  1592 / score :  29.0
#  1590 / score :  34.0
# episode:  1593 / score :  16.0
# episode:  1594 / score :  22.0
# episode:  1595 / score :  19.0
# episode:  1596 / score :  29.0
# episode:  1597 / score :  26.0
# episode:  1598 / score :  19.0
# episode:  1599 / score :  17.0
# episode: episode:   1600 / score :  22.0
# 1601 / score :  20.0
# episode:  1602 / score :  28.0
# episode:  1603episode:  / score :  19.0
#  episode: 1604episode:   1606 / score :  23.0
#  episode: 1605 / score :  24.0
#  1607 / score :  23.0
# / score :  episode:  1608 / score :  21.0
# 28.0
# episode:  1609 / score :  31.0
# episode:  1610 / score :  22.0
# episode:  episode:  1612 / score :  21.0
# 1611 / score :  25.0
# episode:  1613 / score :  23.0
# episode:  1614 / score :  27.0
# episode: episode:   1616 / score :  26.0
# episode: 1615  1617/ score :  30.0
#  / score :  25.0
# episode:  1618 / score :  31.0
# episode:  1619 / score :  13.0
# episode:  episode: 1620 / score :  23.0
#  1621 / score :  18.0
# episode:  1622 / score :  22.0
# episode:  1623 / score :  27.0
# episode: episode: episode:   1625 / score :  22.0
#  1626 / score :  19.0
# 1624 / score :  26.0
# episode:  1627 / score :  27.0
# episode:  1628 / score :  19.0
# episode: episode:  1629  / score :  17.0
# 1630 episode: / score :  17.0
#  episode:  1632 / score :  24.0
# 1631 / score :  episode: 20.0episode:
#  1634 1633 / score :  28.0
#  / score :  25.0
# episode:  1635 / score :  17.0
# episode:  episode: episode:  1638 / score :  20.0
# 1636 / score :  26.0
#  1637 / score :  19.0
# episode:  1639 / score :  23.0
# episode:  1640 / score :  34.0
# episode:  1641 / score :  25.0
# episode:  1642 / score :  27.0
# episode:  1643 / score :  20.0
# episode:  1644episode:  1645 / score :  21.0
#  / score : episode:  1646 / score :  24.0
#  17.0
# episode: episode:  1647 / score :  28.0
#  1648 / score :  24.0
# episode:  1649 / score :  30.0
# episode:  1650 / score :  30.0
# episode:  1651 / score :  21.0
# episode:  1652 / score :  19.0
# episode:  1653 / score :  21.0
# episode:  1654 / score :  28.0
# episode:  1655 / score :  21.0
# episode:  1656 / score :  30.0
# episode: episode:  1657 / score :  26.0
#  1658 / score :  30.0
# episode:  1659 / score :  15.0
# episode: episode:  1661 / score :  32.0
#  1660 / score :  21.0
# episode:  1662 / score :  29.0
# episode:  1663 / score :  23.0
# episode: episode:  1665 / score :  32.0
#  1664 / score :  28.0
# episode:  1666 / score :  32.0
# episode:  1667 / score :  15.0
# episode:  1668 / score :  25.0
# episode:  episode: 1669episode:    / score :  23.0
# 1671 1670 / score :  22.0
# episode: / score :  1672 / score :  31.0
#  23.0
# episode: episode:  1674episode:  / score :  35.0
#  1675 / score :  34.0
#  1673 / score :  28.0
# episode:  1676 / score :  18.0
# episode:  episode: episode: 1677 1678   / score :  20.0
# 1679/ score :  / score :  25.0
#  episode:  1680 / score :  24.0
# 27.0
# episode:  1681 / score :  28.0
# episode:  1682 / score :  25.0
# episode:  1683 / score :  33.0
# episode:  1684 / score :  23.0
# episode:  1685 / score :  15.0
# episode:  1686 / score :  20.0
# episode:  1687 / score :  24.0
# episode:  1688 / score :  34.0
# episode:  1689 / score :  28.0
# episode:  1690 / score :  30.0
# episode:  1691 / score :  32.0
# episode:  1692 / score :  24.0
# episode:  1693 / score :  29.0
# episode:  1694 / score :  32.0
# episode:  1695 / score :  18.0
# episode:  1696 / score :  24.0
# episode: episode:  episode: 1697 1699 / score :  21.0
#   / score : 1698 / score :  23.0
#  24.0
# episode: episode:  1701 / score :  31.0
# episode:  1702 / score :  32.0
#  1700 / score :  31.0
# episode:  1703 / score :  28.0
# episode:  1704episode:  / score :  17.0
# episode:   1706 / score :  23.0
# 1705 episode: / score :   episode: 1707 / score :  28.0
# episode:  170818.0 / score :  21.0
#
# episode:  1709 / score :  29.0
#  1710 / score :  20.0
# episode:  1711 / score :  26.0
# episode:  1712 / score :  25.0
# episode: episode:   1714 / score :  21.0
# 1713 / score :  20.0
# episode: episode:  1715 / score :  27.0
# episode:  1716 / score :  32.0
# episode:  1718 / score :  27.0
#  1717 episode:  1719 / score :  31.0
# / score :  30.0
# episode:  1720 / score :  16.0
# episode:  1721 / score :  16.0
# episode:  1722episode:   1723 / score :  26.0
# / score :  23.0
# episode: episode:   17241725 / score :  20.0
#  / score :  22.0
# episode:  1726 / score :  28.0
# episode:  1727 / score :  37.0
# episode:  1728 / score :  20.0
# episode:  1729 / score :  21.0
# episode:  1730 episode: / score :   13.0
# 1731episode:  episode: 1732 / score :  27.0
#   / score : 1733 / score :  24.0
#  28.0
# episode:  1734 / score :  29.0
# episode: episode:   1736 / score :  32.0
# 1735 / score :  18.0
# episode:  1737 / score :  25.0
# episode: episode:  1738 / score :   1739 / score :  19.0
# episode:  1740 / score :  17.0
# 16.0episode:
#  1741 episode:  / score : episode:  1742 1743 / score :  16.0
# 33.0
#  / score :  26.0
# episode:  1744 / score :  35.0
# episode:  1745 / score :  26.0
# episode:  1746 / score :  16.0
# episode:  episode: episode:   1749 / score :  18.0
# 1748 / score :  33.0
# 1747 / score :  22.0
# episode: episode:  1750 / score :  22.0
#  1751 / score :  23.0
# episode:  1752 / score :  22.0
# episode:  1753 / score :  22.0
# episode:  1754 / score :  18.0
# episode:  1755 / score :  22.0
# episode:  1756 / score :  19.0
# episode:  1757 / score :  18.0
# episode:  1758 / score :  25.0
# episode:  1759 / score :  27.0
# episode:  1760 / score :  25.0
# episode:  1761 / score :  28.0
# episode:  1762 / score :  19.0
# episode: episode:   1764 / score :  18.0
# 1763 / score :  20.0
# episode:  1765 / score :  18.0
# episode:  1766 / score :  18.0
# episode:  1767 episode: / score :  episode:  33.0 1768
# episode: 1769  / score :  27.0
#  episode: 1770 1771/ score :   20.0
# / score :   / score :  23.0
# 27.0episode:
#  1772 / score :  27.0
# episode:  1773 / score :  30.0
# episode:  1774 / score :  29.0
# episode:  1775 / score :  15.0
# episode: episode:  1776 / score :  23.0
# episode:   1778 / score :  27.0
# episode: 1777 1779 / score :  25.0
#  / score :  23.0
# episode: episode:  1780 / score :  24.0
#  1781 / score :  26.0
# episode:  1782 / score :  27.0
# episode:  episode:  1784 / score :  20.0
# episode: 1783  / score :  20.0
# 1785 / score :  18.0
# episode:  1786 / score :  21.0
# episode:  1787 / score :  25.0
# episode:  1788 / score :  25.0
# episode:  1789 / score :  30.0
# episode:  1790episode:   / score : 1791 / score :  13.0
#  episode: 27.0 episode: 1792 / score :  36.0
#
#  1793 / score :  23.0
# episode: episode:   1795 / score :  26.0
# 1794 / score :  27.0
# episode:  1796 / score :  25.0
# episode:  1797 / score :  29.0
# episode:  1798 / score :  16.0
# episode:  1799 / score :  25.0
# episode:  1800 / score :  22.0
# episode: episode:  1802 / score :  23.0
#  1801 / score :  29.0
# episode:  1803 / score :  25.0
# episode:  1804 / score :  21.0
# episode:  1805 / score :  19.0
# episode:  1806 / score :  23.0
# episode:  1807 / score :  32.0
# episode:  1808 / score :  19.0
# episode:  1809 / score :  16.0
# episode:  1810 / score :  28.0
# episode:  1811 / score :  23.0
# episode:  1812episode:  1813 / score :  27.0
#  / score :  23.0
# episode:  1814 / score :  26.0
# episode:  1815 / score :  16.0
# episode:  1816 / score :  23.0
# episode: episode: episode:  1818 / score :  24.0
#  1819 / score :  28.0
#  episode: 1817 1820 / score :  26.0
#  episode:  1821 / score :  21.0
# / score :  22.0
# episode:  1822 / score :  23.0
# episode:  1823 / score :  27.0
# episode:  1824 / score :  17.0
# episode:  1825 / score :  23.0
# episode:  1826 / score :  23.0
# episode: episode:  1827 / score :  22.0
#  1828 / score :  27.0
# episode:  1829 / score :  29.0
# episode:  1830 / score :  26.0
# episode: episode:   1831 / score :  24.0
# 1832 / score :  23.0
# episode: episode: episode:  1833 / score :  27.0
#  1834 / score :  25.0
#  episode: 1835 / score :  27.0
#  episode:  1837 / score :  24.0
# 1836 / score :  24.0
# episode:  1838 / score :  28.0
# episode:  1839 / score :  14.0
# episode:  1840 / score :  18.0
# episode:  1841 / score :  23.0
# episode:  1842 / score :  24.0
# episode:  1843 / score :  34.0
# episode:  1844 / score :  30.0
# episode:  1845 / score :  32.0
# episode:  1846 / score :  29.0
# episode:  1847 / score :  22.0
# episode:  1848 / score :  29.0
# episode:  1849 / score :  15.0
# episode:  1850 / score :  22.0
# episode:  1851 / score :  29.0
# episode:  1852 / score :  31.0
# episode:  1853 / score :  29.0
# episode:  1854 / score :  20.0
# episode:  1855 / score :  28.0
# episode:  1856 / score :  22.0
# episode:  1857 / score :  26.0
# episode:  1858 / score :  21.0
# episode:  1859 / score :  16.0
# episode:  1860 / score :  19.0
# episode:  1861 / score :  18.0
# episode:  1862 / score :  21.0
# episode:  1863 / score :  25.0
# episode:  1864 / score :  20.0
# episode:  1865episode:  / score :  1866 / score :  22.0
# episode:  episode:  1867 / score :  29.0
#  1868 / score :  27.0
# 18.0
# episode:  1869 / score :  16.0
# episode:  1870 / score :  19.0
# episode:  1871 / score :  24.0
# episode:  1872 / score :  27.0
# episode: episode: episode:  1875 / score :  17.0
#   1873 / score :  20.0
# 1874 / score : episode:  17.0
#  1876 / score :  21.0
# episode:  1877 / score :  23.0
# episode:  1878 / score :  23.0
# episode:  1879 / score :  23.0
# episode:  1880 / score :  26.0
# episode: episode:  1881episode:  / score :  23.0
#  1883 / score :  15.0
#  1882 / score :  17.0
# episode:  1884 / score : episode:  1885 / score :  24.0
#  episode: 19.0
# episode:   18861887 / score :  22.0
#  / score :  29.0
# episode:  1888 / score :  39.0
# episode:  episode:  episode: 1889  1891 / score :  24.0
# / score :  26.0
# 1890 episode:  1892 / score :  25.0
# / score :  17.0
# episode:  1893 / score :  21.0
# episode:  1894 / score :  28.0
# episode:  1895 / score :  26.0
# episode:  1896 / score :  25.0
# episode:  1897 / score :  20.0
# episode: episode:  1899 / score :  27.0
#  1898 / score :  21.0
# episode: episode:  1900 / score :  19.0
#  1901 / score :  episode: 22.0 1902 / score :  29.0
#
# episode:  1903 / score :  29.0
# episode:  1904 / score :  14.0
# episode:  1905 / score :  15.0
# episode: episode: episode:  1908 / score :  20.0
#  episode: 1907 / score :  24.0
#   1909 / score :  25.0
# episode: episode:   19061910 / score :  22.0
# 1911  / score :  24.0
# / score :  27.0
# episode:  1912 / score :  19.0
# episode:  1913 / score :  23.0
# episode:  1914 / score :  21.0
# episode:  1915 / score :  24.0
# episode:  1916 / score :  26.0
# episode:  1917 / score :  24.0
# episode:  1918 / score :  33.0
# episode:  1919 / score :  28.0
# episode:  1920 / score :  28.0
# episode:  1921 / score :  30.0
# episode:  1922episode:  1923 / score :  17.0
#  / score :  episode: 26.0
#  1924 / score :  23.0
# episode:  1925 / score :  27.0
# episode:  1926 / score :  21.0
# episode:  1927 / score :  24.0
# episode:  1928 / score :  21.0
# episode:  1929 / score :  20.0
# episode:  1930 / score :  19.0
# episode:  1931 / score :  27.0
# episode: episode:  1932 / score :  22.0
#  1933 episode:  1934 / score :  29.0
# / score :  18.0
# episode: episode: episode:   episode: 1936 / score :  21.0
# 1935 / score :  22.0
#   1937 / score :  31.0
# 1938 / score :  24.0
# episode:  1939 / score :  29.0
# episode:  1940 / score :  26.0
# episode:  1941 / score :  32.0
# episode:  1942 / score :  25.0
# episode:  1943 / score :  27.0
# episode:  1944 / score :  28.0
# episode:  episode:  1945 / score :  33.0
# 1946 / score :  35.0
# episode:  1947 / score :  27.0
# episode:  1948 / score :  28.0
# episode:  1949episode:   1950/ score :  19.0
#  / score :  17.0
# episode:  episode: 1951 / score :  26.0
#  1952 / score :  20.0
# episode:  1953 / score :  24.0
# episode: episode:  1954 / score :  21.0
# episode:  1955 / score :  19.0
#  1956 / score :  33.0
# episode:  1957 / score :  24.0
# episode:  1958 / score :  23.0
# episode:  1959 / score :  18.0
# episode:  1960 / score :  20.0
# episode:  episode:  1962 / score :  29.0
# 1961 / score :  29.0
# episode:  1963 / score :  20.0
# episode:  1964 / score :  25.0
# episode:  1965 episode:  / score :  15.0
# 1966 / score :  22.0
# episode:  1967 / score :  25.0
# episode:  1968 / score :  22.0
# episode:  1969 / score :  30.0
# episode:  1970 / score :  28.0
# episode: episode:  1971 / score :  1972 / score :  23.0
#  30.0
# episode:  1973 / score :  20.0
# episode:  1974 / score :  31.0
# episode: episode:   19751976 / score :  22.0
# episode:  episode:  1977 / score :  32.0
#  1978 / score :  26.0
# / score :  19.0
# episode:  1979 / score :  18.0
# episode:  1980 / score :  28.0
# episode:  1981 / score :  16.0
# episode:  1982 / score :  21.0
# episode:  1983 / score :  24.0
# episode:  1984 / score :  17.0
# episode:  1985 / score :  20.0
# episode:  1986 / score :  28.0
# episode:  1987 / score :  23.0
# episode:  1988 / score :  22.0
# episode:  1989 / score :  17.0
# episode: episode:   1991 / score :  26.0
# 1990 / score :  21.0
# episode:  1992 / score :  25.0
# episode:  episode: 1993 1994 / score :  26.0
#  / score :  25.0
# episode:  1995 / score :  34.0
# episode:  1996 / score :  20.0
# episode:  1997 / score :  22.0
# episode:  episode: 1998 / score :   28.01999 / score :  27.0
# episode:
#  2000 / score :  25.0
# episode:  2001 / score :  28.0
# episode:  2002 / score :  33.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-75c7039909e1> in <module>
#       8
#       9 global_agent = A3CAgent(state_size, action_size, env_name)
# ---> 10 global_agent.train()
#
# <ipython-input-3-524cdac15d94> in train(self)
#     103
#     104         while True:
# --> 105             time.sleep(20)
#     106
#     107             plot = scores[:]
#
# KeyboardInterrupt:
